# %% [markdown]
# ## Ejemplo 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Usar todo lo que aprendimos para automatizar peticiones al API
#     - Guardar nuestros resultados en un archivo tipo .csv
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Veamos cómo usar todo lo que aprendimos para automatizar el proceso de realizar múltiples peticiones a la API, reunirlas en un `DataFrame` y guardarlo en un .csv:

# %%
import pandas as pd
import requests

# %%
url = 'https://api.nasa.gov/neo/rest/v1/neo/browse/'
parametros = {
    'api_key': 'XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt'
}

# %% [markdown]
# Obtener 10 páginas de datos del API.

# %%
diccionarios = []
for i in range(10):
    resultados = requests.get(url, params=parametros)
    if resultados.status_code == 200:
        datos = resultados.json()
        objetos = datos["near_earth_objects"]
        diccionarios.append(objetos)
        url = datos ["links"]["next"]
        parametro = {}
        print(datos["links"]["self"])
    else:
        print("Error al obtener la página")
# Out:
# http://www.neowsapp.com/rest/v1/neo/browse?page=0&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=1&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=2&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=3&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=4&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=5&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=6&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=7&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=8&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt
# http://www.neowsapp.com/rest/v1/neo/browse?page=9&size=20&api_key=XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt,XI4lyP5eeMKNS5ZooqY073Gll4dIaOxwTXnVgLVt

# %% [markdown]
# Valiando la cantidad de diccionarios obtenidos:

# %%
len(diccionarios)
# Out:
# 10

# %% [markdown]
# Validando el tipo de dato del elemento 0 de la lista:

# %%
type(diccionarios[0])
# Out:
# list

# %% [markdown]
# Normalizar y crea los dataframes usando `map` o listas de compresión:

# %%
dfs = [pd.json_normalize(d) for d in diccionarios]

# %% [markdown]
# Valida el tipo de dato del elemento 0:

# %%
type(dfs[0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Explora el inicio del dataframe del elemento 0:

# %%
dfs[0].head()
# Out:
#         id neo_reference_id                      name name_limited  \
# 0  2004034          2004034     4034 Vishnu (1986 PA)       Vishnu
# 1  2004055          2004055  4055 Magellan (1985 DO2)     Magellan
# 2  2004179          2004179   4179 Toutatis (1989 AC)     Toutatis
# 3  2004183          2004183       4183 Cuno (1959 LM)         Cuno
# 4  2004197          2004197   4197 Morpheus (1982 TA)     Morpheus
#
#   designation                                   nasa_jpl_url  \
# 0        4034  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004034
# 1        4055  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004055
# 2        4179  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004179
# 3        4183  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004183
# 4        4197  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004197
#
#    absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                 18.32                               True
# 1                 14.71                              False
# 2                 15.24                               True
# 3                 14.11                               True
# 4                 14.91                              False
#
#                                  close_approach_data  is_sentry_object  ...  \
# 0  [{'close_approach_date': '1901-08-21', 'close_...             False  ...
# 1  [{'close_approach_date': '1902-08-30', 'close_...             False  ...
# 2  [{'close_approach_date': '1903-01-24', 'close_...             False  ...
# 3  [{'close_approach_date': '1903-09-16', 'close_...             False  ...
# 4  [{'close_approach_date': '1906-05-26', 'close_...             False  ...
#
#   orbital_data.perihelion_distance  orbital_data.perihelion_argument  \
# 0                 .588998629780359                 296.7001970709545
# 1                1.226626612246686                 154.3928395095554
# 2                 .956497226209777                 277.9991177324344
# 3                .7253371795917459                 236.3984059681077
# 4                .5216956988048178                 122.5555093581483
#
#    orbital_data.aphelion_distance  orbital_data.perihelion_time  \
# 0               1.530150913452289          2459117.217047231721
# 1               2.414144907891243          2459037.386791628232
# 2               4.132494159807088          2459201.250945573887
# 3               3.242801194500169          2459081.800976721272
# 4               4.067403948937319          2459341.688184719180
#
#    orbital_data.mean_anomaly  orbital_data.mean_motion  orbital_data.equinox  \
# 0           75.2597505628063         .9036633315848436                 J2000
# 1          144.1087358617548         .4012905471095006                 J2000
# 2          359.8176482415533         .2428295269160061                 J2000
# 3          110.9849907476976          .352670273937897                 J2000
# 4           15.5428988510504         .2835684016560779                 J2000
#
#    orbital_data.orbit_class.orbit_class_type  \
# 0                                        APO
# 1                                        AMO
# 2                                        APO
# 3                                        APO
# 4                                        APO
#
#     orbital_data.orbit_class.orbit_class_description  \
# 0  Near-Earth asteroid orbits which cross the Ear...
# 1  Near-Earth asteroid orbits similar to that of ...
# 2  Near-Earth asteroid orbits which cross the Ear...
# 3  Near-Earth asteroid orbits which cross the Ear...
# 4  Near-Earth asteroid orbits which cross the Ear...
#
#           orbital_data.orbit_class.orbit_class_range
# 0  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 1                 1.017 AU < q (perihelion) < 1.3 AU
# 2  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 3  a (semi-major axis) > 1.0 AU; q (perihelion) <...
# 4  a (semi-major axis) > 1.0 AU; q (perihelion) <...
#
# [5 rows x 44 columns]

# %% [markdown]
# Concatena los dataframes en un sólo dataframe y reinicia índices (por alguna buena razón hemos creado una lista de dataframes ¿cierto?):

# %%
df = pd.concat(dfs)

df
# Out:
#          id neo_reference_id                      name name_limited  \
# 0   2004034          2004034     4034 Vishnu (1986 PA)       Vishnu
# 1   2004055          2004055  4055 Magellan (1985 DO2)     Magellan
# 2   2004179          2004179   4179 Toutatis (1989 AC)     Toutatis
# 3   2004183          2004183       4183 Cuno (1959 LM)         Cuno
# 4   2004197          2004197   4197 Morpheus (1982 TA)     Morpheus
# ..      ...              ...                       ...          ...
# 15  2036183          2036183         36183 (1999 TX16)          NaN
# 16  2036236          2036236           36236 (1999 VV)          NaN
# 17  2036284          2036284          36284 (2000 DM8)          NaN
# 18  2037336          2037336           37336 (2001 RM)          NaN
# 19  2037638          2037638           37638 (1993 VB)          NaN
#
#    designation                                   nasa_jpl_url  \
# 0         4034  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004034
# 1         4055  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004055
# 2         4179  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004179
# 3         4183  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004183
# 4         4197  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004197
# ..         ...                                            ...
# 15       36183  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036183
# 16       36236  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036236
# 17       36284  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036284
# 18       37336  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2037336
# 19       37638  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2037638
#
#     absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                  18.32                               True
# 1                  14.71                              False
# 2                  15.24                               True
# 3                  14.11                               True
# 4                  14.91                              False
# ..                   ...                                ...
# 15                 16.30                              False
# 16                 15.89                              False
# 17                 14.94                              False
# 18                 15.63                              False
# 19                 19.30                               True
#
#                                   close_approach_data  is_sentry_object  ...  \
# 0   [{'close_approach_date': '1901-08-21', 'close_...             False  ...
# 1   [{'close_approach_date': '1902-08-30', 'close_...             False  ...
# 2   [{'close_approach_date': '1903-01-24', 'close_...             False  ...
# 3   [{'close_approach_date': '1903-09-16', 'close_...             False  ...
# 4   [{'close_approach_date': '1906-05-26', 'close_...             False  ...
# ..                                                ...               ...  ...
# 15  [{'close_approach_date': '1908-11-26', 'close_...             False  ...
# 16  [{'close_approach_date': '1902-05-29', 'close_...             False  ...
# 17  [{'close_approach_date': '1908-07-29', 'close_...             False  ...
# 18  [{'close_approach_date': '1913-10-25', 'close_...             False  ...
# 19  [{'close_approach_date': '1906-12-03', 'close_...             False  ...
#
#    orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                 296.7001970709545               1.530150913452289
# 1                 154.3928395095554               2.414144907891243
# 2                 277.9991177324344               4.132494159807088
# 3                 236.3984059681077               3.242801194500169
# 4                 122.5555093581483               4.067403948937319
# ..                              ...                             ...
# 15                 311.164209075178               2.066772497052938
# 16                19.78160441199078               1.897072872349065
# 17                317.9627552342487               2.305331222145377
# 18                117.9993607106022               3.342490141039897
# 19                 323.115958927725                2.90216007459676
#
#     orbital_data.perihelion_time  orbital_data.mean_anomaly  \
# 0           2459117.217047231721           75.2597505628063
# 1           2459037.386791628232          144.1087358617548
# 2           2459201.250945573887          359.8176482415533
# 3           2459081.800976721272          110.9849907476976
# 4           2459341.688184719180           15.5428988510504
# ..                           ...                        ...
# 15          2459172.329104617749          14.37088082809856
# 16          2459163.994165011957           23.3928669810526
# 17          2459704.341780239671          192.1206587502915
# 18          2459538.107168056208          318.7237210277229
# 19          2459001.280611793807          74.43388069050786
#
#     orbital_data.mean_motion  orbital_data.equinox  \
# 0          .9036633315848436                 J2000
# 1          .4012905471095006                 J2000
# 2          .2428295269160061                 J2000
# 3           .352670273937897                 J2000
# 4          .2835684016560779                 J2000
# ..                       ...                   ...
# 15         .5101321996727431                 J2000
# 16         .6407980255406982                 J2000
# 17          .545342939217041                 J2000
# 18         .2914843898007574                 J2000
# 19         .3736276943761538                 J2000
#
#     orbital_data.orbit_class.orbit_class_type  \
# 0                                         APO
# 1                                         AMO
# 2                                         APO
# 3                                         APO
# 4                                         APO
# ..                                        ...
# 15                                        AMO
# 16                                        APO
# 17                                        APO
# 18                                        AMO
# 19                                        APO
#
#      orbital_data.orbit_class.orbit_class_description  \
# 0   Near-Earth asteroid orbits which cross the Ear...
# 1   Near-Earth asteroid orbits similar to that of ...
# 2   Near-Earth asteroid orbits which cross the Ear...
# 3   Near-Earth asteroid orbits which cross the Ear...
# 4   Near-Earth asteroid orbits which cross the Ear...
# ..                                                ...
# 15  Near-Earth asteroid orbits similar to that of ...
# 16  Near-Earth asteroid orbits which cross the Ear...
# 17  Near-Earth asteroid orbits which cross the Ear...
# 18  Near-Earth asteroid orbits similar to that of ...
# 19  Near-Earth asteroid orbits which cross the Ear...
#
#            orbital_data.orbit_class.orbit_class_range sentry_data
# 0   a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 1                  1.017 AU < q (perihelion) < 1.3 AU         NaN
# 2   a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 3   a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 4   a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# ..                                                ...         ...
# 15                 1.017 AU < q (perihelion) < 1.3 AU         NaN
# 16  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 17  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 18                 1.017 AU < q (perihelion) < 1.3 AU         NaN
# 19  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
#
# [200 rows x 45 columns]

# %% [markdown]
# Comprobemos la cantidad de objetos en el dataframe final, 10 páginas con 20 objetos cada una:

# %%
df_1 = df.reset_index(drop=True)
df_1
# Out:
#           id neo_reference_id                      name name_limited  \
# 0    2004034          2004034     4034 Vishnu (1986 PA)       Vishnu
# 1    2004055          2004055  4055 Magellan (1985 DO2)     Magellan
# 2    2004179          2004179   4179 Toutatis (1989 AC)     Toutatis
# 3    2004183          2004183       4183 Cuno (1959 LM)         Cuno
# 4    2004197          2004197   4197 Morpheus (1982 TA)     Morpheus
# ..       ...              ...                       ...          ...
# 195  2036183          2036183         36183 (1999 TX16)          NaN
# 196  2036236          2036236           36236 (1999 VV)          NaN
# 197  2036284          2036284          36284 (2000 DM8)          NaN
# 198  2037336          2037336           37336 (2001 RM)          NaN
# 199  2037638          2037638           37638 (1993 VB)          NaN
#
#     designation                                   nasa_jpl_url  \
# 0          4034  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004034
# 1          4055  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004055
# 2          4179  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004179
# 3          4183  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004183
# 4          4197  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004197
# ..          ...                                            ...
# 195       36183  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036183
# 196       36236  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036236
# 197       36284  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2036284
# 198       37336  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2037336
# 199       37638  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2037638
#
#      absolute_magnitude_h  is_potentially_hazardous_asteroid  \
# 0                   18.32                               True
# 1                   14.71                              False
# 2                   15.24                               True
# 3                   14.11                               True
# 4                   14.91                              False
# ..                    ...                                ...
# 195                 16.30                              False
# 196                 15.89                              False
# 197                 14.94                              False
# 198                 15.63                              False
# 199                 19.30                               True
#
#                                    close_approach_data  is_sentry_object  ...  \
# 0    [{'close_approach_date': '1901-08-21', 'close_...             False  ...
# 1    [{'close_approach_date': '1902-08-30', 'close_...             False  ...
# 2    [{'close_approach_date': '1903-01-24', 'close_...             False  ...
# 3    [{'close_approach_date': '1903-09-16', 'close_...             False  ...
# 4    [{'close_approach_date': '1906-05-26', 'close_...             False  ...
# ..                                                 ...               ...  ...
# 195  [{'close_approach_date': '1908-11-26', 'close_...             False  ...
# 196  [{'close_approach_date': '1902-05-29', 'close_...             False  ...
# 197  [{'close_approach_date': '1908-07-29', 'close_...             False  ...
# 198  [{'close_approach_date': '1913-10-25', 'close_...             False  ...
# 199  [{'close_approach_date': '1906-12-03', 'close_...             False  ...
#
#     orbital_data.perihelion_argument  orbital_data.aphelion_distance  \
# 0                  296.7001970709545               1.530150913452289
# 1                  154.3928395095554               2.414144907891243
# 2                  277.9991177324344               4.132494159807088
# 3                  236.3984059681077               3.242801194500169
# 4                  122.5555093581483               4.067403948937319
# ..                               ...                             ...
# 195                 311.164209075178               2.066772497052938
# 196                19.78160441199078               1.897072872349065
# 197                317.9627552342487               2.305331222145377
# 198                117.9993607106022               3.342490141039897
# 199                 323.115958927725                2.90216007459676
#
#      orbital_data.perihelion_time  orbital_data.mean_anomaly  \
# 0            2459117.217047231721           75.2597505628063
# 1            2459037.386791628232          144.1087358617548
# 2            2459201.250945573887          359.8176482415533
# 3            2459081.800976721272          110.9849907476976
# 4            2459341.688184719180           15.5428988510504
# ..                            ...                        ...
# 195          2459172.329104617749          14.37088082809856
# 196          2459163.994165011957           23.3928669810526
# 197          2459704.341780239671          192.1206587502915
# 198          2459538.107168056208          318.7237210277229
# 199          2459001.280611793807          74.43388069050786
#
#      orbital_data.mean_motion  orbital_data.equinox  \
# 0           .9036633315848436                 J2000
# 1           .4012905471095006                 J2000
# 2           .2428295269160061                 J2000
# 3            .352670273937897                 J2000
# 4           .2835684016560779                 J2000
# ..                        ...                   ...
# 195         .5101321996727431                 J2000
# 196         .6407980255406982                 J2000
# 197          .545342939217041                 J2000
# 198         .2914843898007574                 J2000
# 199         .3736276943761538                 J2000
#
#      orbital_data.orbit_class.orbit_class_type  \
# 0                                          APO
# 1                                          AMO
# 2                                          APO
# 3                                          APO
# 4                                          APO
# ..                                         ...
# 195                                        AMO
# 196                                        APO
# 197                                        APO
# 198                                        AMO
# 199                                        APO
#
#       orbital_data.orbit_class.orbit_class_description  \
# 0    Near-Earth asteroid orbits which cross the Ear...
# 1    Near-Earth asteroid orbits similar to that of ...
# 2    Near-Earth asteroid orbits which cross the Ear...
# 3    Near-Earth asteroid orbits which cross the Ear...
# 4    Near-Earth asteroid orbits which cross the Ear...
# ..                                                 ...
# 195  Near-Earth asteroid orbits similar to that of ...
# 196  Near-Earth asteroid orbits which cross the Ear...
# 197  Near-Earth asteroid orbits which cross the Ear...
# 198  Near-Earth asteroid orbits similar to that of ...
# 199  Near-Earth asteroid orbits which cross the Ear...
#
#             orbital_data.orbit_class.orbit_class_range sentry_data
# 0    a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 1                   1.017 AU < q (perihelion) < 1.3 AU         NaN
# 2    a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 3    a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 4    a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# ..                                                 ...         ...
# 195                 1.017 AU < q (perihelion) < 1.3 AU         NaN
# 196  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 197  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
# 198                 1.017 AU < q (perihelion) < 1.3 AU         NaN
# 199  a (semi-major axis) > 1.0 AU; q (perihelion) <...         NaN
#
# [200 rows x 45 columns]

# %% [markdown]
# Guarda tu dataframe en el archivo `objetos_tierra_nasa.csv`:

# %%
df_1.to_csv("objetos_tierra_nasa.csv")

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Automatizando peticiones
#
# ### 1. Objetivos:
#     - Automatizar la petición de datos a la API de la NASA por fechas.
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# ### a) Automatizando peticiones
#
# En el primer Reto realizaste una petición a la API de la NASA para pedir 5 datos de la hoja #100. Ahora, vamos a automatizar el proceso de realizar peticiones a la API para obtener una cantidad bastante mayor de datos.
#
# Vamos a obtener ahora los datos por fechas, así que tendrás que ir a la página de la [api de la NASA](https://api.nasa.gov/), para revisar cómo es posible realizar peticiones por fecha. Queremos obtener los **dos primeros meses (Enero y Febrero) del año 1995**. Observa que la API sólo permite peticiones por fecha en rangos de 7 días.
#
# Tu reto tiene los siguientes pasos:
#
# 1. Revisa la documentación de la API de la NASA para entender cómo realizar peticiones por fecha.
# 2. Realiza una primera petición de prueba para entender el formato de los datos que obtienes de regreso (cómo extraemos los datos que necesitamos y qué estructura tienen).
# 2. Escribe el código necesario para automatizar las peticiones a la API y obtener los meses de Enero y Febrero del año 1995.
# 3. Almacena los datos de cada petición y luego usa esos datos para crear `DataFrames`.
# 4. Concatena verticalmente tus `DataFrames` para obtener un `DataFrame` final que contenga todos los datos de tus peticiones. Cada fila tiene que corresponder a un objeto espacial.
# 5. Guarda tu `DataFrame` con el nombre de `near_earth_objects-january_february_1995-raw.csv`.
#
# > **Nota**: En este momento no te preocupes por explorar o limpiar tu dataset. Eso lo haremos en la siguiente sesión. Lo que sí tienes que asegurarte es de normalizar tus datos antes de convertirlos en `DataFrame`.
#
# ¡Mucha suerte!
